# %%
#!pip install opencv-python

# %%
import cv2
print(cv2.__version__)

from matplotlib import pyplot as plt

import numpy as np
# Out:
# 4.8.0

# %%
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

image = cv2.imread('./images/castara.jpeg')
imshow(title='Castara',image=image)

# %%
image.shape[:2] # (1200, 1920) (height, width)
def imshow(title = "", image = None, size = 10):
 
    h, w = image.shape[0], image.shape[1]
    aspect_ratio = h/w
    
    plt.figure(figsize=(size * 0.3, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

imshow("Castara", image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

imshow("Converted to Grayscale", gray_image)

# %%
print(image.shape)
print(gray_image.shape) # just one dim for the channels
# Out:
# (1280, 960, 3)
# (1280, 960)
